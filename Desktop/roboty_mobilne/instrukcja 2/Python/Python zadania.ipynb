# %% [markdown]
# ## Zadanie 1

# %% [markdown]
# Utworzyć zmienną tekstowoą przechowującą tekst "Roboty mobilne - laboratorium". Wyświetlić tekst, a następnie utworzyć i wyświetlić zmienną tablicową rozdzielonyTekst, która będzie przechowywała rozdzielony tekst po spacjach. Można wykorzystać metodę split.

# %% [markdown]
# ## Zadanie 2

# %% [markdown]
# Wykorzystać utworzoną zmienną rozdzielonyTekst z zadania pierwszego do wyświetlenia tekstu sformatowanego następująco:
# "Liczba rozdzielonych elementów wynosi x. Pierwszy i drugi przechowywany wyraz to Wyraz1 Wyraz2."
#
# gdzie w miejsce x wstawiana jest liczba elementów znajdująca się w zmiennej rozdzielonyTekst,
# Wyraz1 oznacza pierwszy element tablicy rozdzielonyTekst, natomiast Wyraz2 drugi element. Zadanie należy zrealizować z wykorzystaniem tylko jednego polecenia print.

# %% [markdown]
# ## Zadanie 3

# %% [markdown]
# Napisać funkcję, która jako argument przyjmuje liczbę zmiennoprzecinkową i podnosi ją do potęgi 3. Do potęgi podnoszone są tylko liczby z zakresu/przedziału od (0,25>. Jeśli liczba jest spoza tego zakresu pojawia się komunikat:
# "Podany argument nie należy do zakresu (0,25>"
# Jeśli natomiast liczba znajduje się w podanym zakresie to wyświetlany jest następujący komunikat:
# "Podana liczba x podniesiona do potęgi trzeciej wynosi y"
#
# x - podana jako argument liczba
#
# y - x podniesiony do potęgi 3, wynik wyświetlany z dokładnością do dwóch miejsc po przecinku
#
# Wywołać funkcję dla następujących argumentów -4, 5.5, 25

# %%
# definicja i implementacja funkcji

# %%
# wywołanie funkcji
