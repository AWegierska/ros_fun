# %% [markdown]
# Do wykonania ćwiczeń należy uruchomić w terminalach następujące symulacje:
#
# - **rosrun turtlesim turtlesim_node**
# - **roslaunch multirobot_nav multi_turtlebot3.launch**
# - **roslaunch multirobot_nav multi_nav.launch**

# %% [markdown]
# #  Zadania - Terminal

# %% [markdown]
# ### Zadanie 1
# Wyświetlić informację dla topiców, podać nazwę paczki i typu wiadomości.
#
# - /turtle1/cmd_vel - prędkości sterujące robotem
# - /turtle1/color_sensor - kolor
# - /turtle1/pose - położenie robota

# %%
! Do uzupełnienia komenda w terminalu
# Nazwa paczki: 
# Nazwa typu wiadomości:

# %%
! Do uzupełnienia komenda w terminalu
# Nazwa paczki: 
# Nazwa typu wiadomości:

# %%
! Do uzupełnienia komenda w terminalu
# Nazwa paczki: 
# Nazwa typu wiadomości:

# %% [markdown]
# ### Zadanie 2
# Wyświetlić typ dla topiców, podać nazwę paczki i typ wiadomości
#
# - /tb3_2/scan
# - /tb3_2/map
# - /tf
# - /tb3_2/move_base_simple/goal

# %%
! Do uzupełnienia komenda w terminalu
# Nazwa paczki: 
# Nazwa typu wiadomości:

# %%
! Do uzupełnienia komenda w terminalu
# Nazwa paczki: 
# Nazwa typu wiadomości:

# %%
! Do uzupełnienia komenda w terminalu
# Nazwa paczki: 
# Nazwa typu wiadomości:

# %%
! Do uzupełnienia komenda w terminalu
# Nazwa paczki: 
# Nazwa typu wiadomości:

# %% [markdown]
# ### Zadanie 3
# Wyświetlić strukturę (pola) w wiadomości dla podanych typów:
#
# - geometry_msgs/Pose
#
# - sensor_msgs/PointCloud
#
# - nav_msgs/Odometry

# %%
! Do uzupełnienia komenda w terminalu

# %%
! Do uzupełnienia komenda w terminalu

# %%
! Do uzupełnienia komenda w terminalu

# %% [markdown]
# ### Zadanie 4
# Dla wiadomości na topicu */tb3_2/imu* wyświetlić aktualne przyspieszenie kątowe dla zamontowanego na robocie IMU.
# Należy wyświetlić tylko pole z wiadomości o nazwie *angular_velocity*.

# %%
! Do uzupełnienia komendy w terminalu

# %% [markdown]
# # Python - Publisher.
# Utworzyć Publishera, który na topicu o podanej nazwie będzie publikował wiadomość wskazanego typu. Uzupełnić wybrane pola w wiadomości. Poprawność realizacji zadania można monitorować przy włączonym nasłuchiwaniu wiadomości na topicu o tej samej nazwie. (*rostopic echo nazwa_topicu*)
#
# Do realizacji zadania można wykonać następujące kroki:
# 1. Wyświetlić strukturę wiadomości
# 2. Zaimportować odpowiedni typ wiadomości
# 3. Utworzyć obiekt Publishera i podać właściwe argumenty
# 4. Utworzyć obiekt wiadomości
# 5. Uzupełnić dowolne pola wiadomości
# 6. Wysłać wiadomość

# %%
# import biblioteki
import rospy
# utworzenie node'a
rospy.init_node("topics_zadania", anonymous=True)

# %% [markdown]
# ### Zadanie 5
# Na topicu "informacja" wysłać dowolną wiadomość tekstową typu std_msgs/String.

# %% [markdown]
# ### Zadanie 6
# Na topicu "liczba_zadan" wysłać dowolną wartosć wskazującą na liczbę zadań do realizacji. Wysłana wiadomość powinna być typu std_msgs/Int16.

# %% [markdown]
# ### Zadanie 7
# Po użyciu polecenia
#
# **rostopic type robot_pose**
#
# otrzymano następującą informację
#
# **geometry_msgs/Pose**
#
# Na podstawie powyższych informacji należy utworzyć Publishera i opublikować dowolną wiadomość na tym topicu.

# %% [markdown]
# ### Zadanie 8
# Na topicu robot_target_goal opublikować wiadomość z paczki mbf_msgs typu MoveBaseGoal.

# %% [markdown]
# ### Zadanie 9
# Na topicu robot_laser opubikować wiadomość tego samego typu co na topicu /tb3_2/laser.

# %% [markdown]
# # Python - Subscriber
# Należy utworzyć Subscribera, który na topicu o podanej nazwie będzie odbierał wiadomość wskazanego typu. Należy wyświetlić wybrane pola z wiadomości, które zawierają niezerowe wartości.
#
# Do realizacji zadania można wykonać następujące kroki:
# 1. Wyświetlić strukturę wiadomości
# 2. Zaimportować odpowiedni typ wiadomości
# 3. Utworzyć obiekt Subscribera i podać właściwe argumenty
# 4. Utworzyć funkcję callback
# 5. Wyświetlić dowolne pola z wiadomości

# %% [markdown]
# ### Zadanie 10
# Odebrać wiadomość na topicu "/robot2_pose" wiadomość typu Pose z paczki geometry_msgs.

# %%
# Opublikowanie przykładowej wiadomości do stwierdzenia poprawności 
# działania Subscribera.

!(rostopic pub --once /robot2_pose geometry_msgs/Pose \
  "{position: {x: 1.0, y: 2.0, z: 0.0}, \
  orientation: {x: 0.0, y: 0.0, z: 0.0}}")

# %% [markdown]
# ### Zadanie 11
# Z topicu "/tb3_1/imu" odebrać przychodzące informacje o aktualnych danych z czunika IMU i zapisać je w zmiennej
# globalnej. W oddzielnym bloku umieścić kod odpowiedzialny za wyświetlanie wszystkich danych ze zmiennej globalnej z pola angular_velocity. Zmienna globalna powinna być tego samego typu co odbierana wiadomość z "/tb3_1/imu"

# %% [markdown]
# ### Zadanie 12
# Z topicu "/tb3_2/scan" odebrać przychodzące informacje o aktualnych danych ze skanera laserowego i zapisać je w zmiennej globalnej. W oddzielnym bloku umieścić kod odpowiedzialny za wyświetlanie kompletnej odebranej wiadomości.
# Zmienna globalna powinna być tego samego typu co odbierana wiadomość z "/tb3_2/scan"
