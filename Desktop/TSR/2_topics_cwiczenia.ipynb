# %% [markdown]
# Do wykonania ćwiczeń należy uruchomić w terminalu symulacje z turtlesim:

# %% [markdown]
# **rosrun turtlesim turtlesim_node**

# %% [markdown]
# oraz turtlebot3

# %% [markdown]
# **roslaunch multirobot_nav multi_turtlebot3.launch**

# %% [markdown]
# **roslaunch multirobot_nav multi_nav.launch**

# %% [markdown]
# #  Terminal

# %% [markdown]
# ### Zadanie 1
# Wyświetlić informację dla topiców
#
# - /turtle1/cmd_vel - prędkości sterujące robotem
#
# - /turtle1/color_sensor - kolor
#
# - /turtle1/pose - położenie robota

# %% [markdown]
# ### Zadanie 2
# Wyświetlić typ dla topiców:
#
# - /turtle1/pose
#
# - /tb3_2/laser
#
# - /turtle1/cmd_vel

# %% [markdown]
# ### Zadanie 3
# Wyświetlić strukturę (pola) w wiadomości dla podanych typów:
#
# - geometry_msgs/Pose
#
# - sensor_msgs/PointCloud
#
# - nav_msgs/Odometry

# %% [markdown]
# # Python
# Dla podanych topiców utworzyć Publishera i Subscribera. Dla Publishera należy uzupełnić dowolnie wybrane pola natomiast dla Subscriber'a należy odczytać dowolnie wybrane pola.
# Należy pamiętać o kolejnych krokach do osiągnięcia celu:
#
# 1. Sprawdzenie typu wiadomości
#
# 2. Wyświetlenie struktury wiadomości
#
# 3. Import odpowiednich typów wiadomości
#
# 4. Dla publishera
#
#     - utworzenie obiektu Publishera i uzupełnienie go odpowiednią nazwą i typem
#
#     - utworzenie wiadomości
#
#     - uzupełnienie pól wiadomości
#
#     - wysłanie wiadomości
#
# 4. Dla Subscribera
#
#     - utworzenie funkcji callback wywoływanej przez subscribera po odebraniu wiadomości na zadanym topicu
#
#     - utworzenie subscribera z prawidłowo uzupełniona nazwą topicu i typu wiadomości

# %%
# import biblioteki
import rospy
# utworzenie node'a
rospy.init_node("topics_test", anonymous=True)

# %% [markdown]
# ### Zadanie 4
# /turtle1/pose

# %% [markdown]
# ### Zadanie 5
# /tb3_2/odom

# %% [markdown]
# ### Zadanie 6
# /tb3_2/laser

# %% [markdown]
# ### Zadanie 7
# /tb3_2/cmd_vel
