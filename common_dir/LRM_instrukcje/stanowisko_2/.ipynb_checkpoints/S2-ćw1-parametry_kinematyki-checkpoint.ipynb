# %% [markdown]
# ## Stanowisko 2 - napęd skid-steer
#
# <p style="text-align:center; font-size:24px;">Parametry fizyczne</p>
#
# **Poniżej należy zdefiniować wszystkie stałe związane z parametrami konstrukcyjnymi robota**
#
# **Należy założyć, że początek układu robota jest zlokalizowany po środku platformy.**
#
# Promień koła to 0.033 m
# <img src="../images/TB3_2_drawings.png" alt="System architecture" width="1500"/>
#
# <img src="../images/numeracja_kol_skid_steer.png" alt="System architecture" width="750"/>
#
# **Numeracja kół dla robota z napędem skid-steer.**
#
# ## <span style="color:red">Uzupełnij poniższą komórkę. (1/1)</span>

# %%
import numpy as np
#Wheel 1
#współrzędne koła w układzie robota
x1 =
y1 =

# Poniższe parametry (l, alpha, beta) należy opisać wzorami. Jeśli wpisana 
# została tylko wartość to w sprawozdaniu należy opisać sposób wyprowadzenia 
# tych wartości.

#odległość koła od początku układu robota
l1 =
#kąty opisujące orientację koła
alpha1 =
beta1 =

#Wheel 2

#Wheel 3

#Wheel 4

# %%
# Wyświetlanie parametrów kinematyki dla Wheel 1
print(x1)
print(y1)
print(l1)
print(alpha1)
print(beta1)
